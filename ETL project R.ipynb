# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#store csv into dataframe.
df_cab = pd.read_csv('Resources/carlisting.csv')
df_weather = pd.read_csv('Resources/carlisting_weather.csv')
df_car_listing = pd.read_csv('Resources/carlisting_weather_grouped.csv')

# %%
engine = create_engine("postgresql://postgres:9012@Hunt@localhost/Project 2")
connection = engine.connect()

# %%
df_car_listing.to_sql(name='carlisting_weather_grouped', con=connection, if_exists='append', index=False)

# %%
#load dataframe into database
df_cab.to_sql(name='carlisting', con=connection, if_exists='append', index=False)

# %%
df_weather.to_sql(name='carlisting_weather', con=connection, if_exists='append', index=False)

# %%
#confirm data
pd.read_sql_query('select * from carlisting_weather_grouped', con=connection).head()
# Out:
#    Unnamed: 0        date  num_of_listing  avg_price   avg_temp  avg_rain  \
# 0           0  2018-12-13            1256     9737.0  39.369733  0.072744
# 1           1  2018-12-14             635    10909.0  38.728596  0.068275
# 2           2  2018-12-15             387     9007.0  39.032753  0.099985
# 3           3  2018-12-16             569     9766.0  39.052143  0.041430
#
#    avg_humidity
# 0      0.768717
# 1      0.753656
# 2      0.766264
# 3      0.755969

# %%
#confirm data
pd.read_sql_query('select * from carlisting', con=engine).head()
# Out:
#    Unnamed: 0        date                                              Title  \
# 0           0  2018-12-16                   Assorted cars, trucks and planes
# 1           1  2018-12-16       05 fordMINT! 200hp TAURUS"sel!" 2 to choose!
# 2           2  2018-12-16  2007 VOLVO s80  loaded! ma. inspected!  +LOW M...
# 3           3  2018-12-16         2002 1 owner HONDA! loaded se xmas gift!!!
# 4           4  2018-12-16   IROC Camaro Parts 1986   HAVE 2 OTHER PARTS CARS
#
#    Price                                              Links
# 0      1  https://boston.craigslist.org/nos/tag/d/readin...
# 1   1595  https://boston.craigslist.org/gbs/cto/d/medfor...
# 2   2975  https://boston.craigslist.org/gbs/cto/d/medfor...
# 3   1595  https://boston.craigslist.org/gbs/cto/d/barre-...
# 4      0  https://boston.craigslist.org/bmw/pts/d/iroc-c...

# %%
#confirm data
pd.read_sql_query('select * from carlisting_weather', con=engine).head()
# Out:
#    Unnamed: 0        date                                              Title  \
# 0           0  2018-12-16                   Assorted cars, trucks and planes
# 1           1  2018-12-16       05 fordMINT! 200hp TAURUS"sel!" 2 to choose!
# 2           2  2018-12-16  2007 VOLVO s80  loaded! ma. inspected!  +LOW M...
# 3           3  2018-12-16         2002 1 owner HONDA! loaded se xmas gift!!!
# 4           4  2018-12-16   IROC Camaro Parts 1986   HAVE 2 OTHER PARTS CARS
#
#    Price                                              Links   avg_temp  \
# 0      1  https://boston.craigslist.org/nos/tag/d/readin...  39.052143
# 1   1595  https://boston.craigslist.org/gbs/cto/d/medfor...  39.052143
# 2   2975  https://boston.craigslist.org/gbs/cto/d/medfor...  39.052143
# 3   1595  https://boston.craigslist.org/gbs/cto/d/barre-...  39.052143
# 4      0  https://boston.craigslist.org/bmw/pts/d/iroc-c...  39.052143
#
#    avg_rain  avg_humidity
# 0   0.04143      0.755969
# ...
